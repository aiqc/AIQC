# %%
import os
os.chdir('/Users/layne/Desktop/aiqc')
os.getcwd()
# Out:
# '/Users/layne/Desktop/aiqc'

# %%
import aiqc
from aiqc import datum
# Out:
# /Users/layne/.pyenv/versions/3.7.6/envs/jupyterlab/lib/python3.7/site-packages/pandas/compat/__init__.py:97: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
datum.list_datums(format='df')
# Out:
#                     name dataset_type          analysis_type         label  \
# 0     exoplanets.parquet      tabular             regression  SurfaceTempK
# 1  heart_failure.parquet      tabular             regression          died
# 2               iris.tsv      tabular   classification_multi       species
# 3              sonar.csv      tabular  classification_binary        object
# 4             houses.csv      tabular             regression         price
# 5     iris_noHeaders.csv      tabular   classification multi       species
# 6           iris_10x.tsv      tabular   classification multi       species
# 7            brain_tumor        image  classification_binary        status
#
#   label_classes    features  samples  \
# 0           N/A           8      433
# 1             2          12      299
# 2             3           4      150
# 3             2          60      208
# 4           N/A          12      506
# 5             3           4      150
# ...

# %%
names = datum.list_datums(format='df')['name']

# %%
for n in names:
    print(datum.get_datum_path(file_name=n))
# Out:
# /Users/layne/Desktop/aiqc/aiqc/data/exoplanets.parquet
# /Users/layne/Desktop/aiqc/aiqc/data/heart_failure.parquet
# /Users/layne/Desktop/aiqc/aiqc/data/iris.tsv
# /Users/layne/Desktop/aiqc/aiqc/data/sonar.csv
# /Users/layne/Desktop/aiqc/aiqc/data/houses.csv
# /Users/layne/Desktop/aiqc/aiqc/data/iris_noHeaders.csv
# /Users/layne/Desktop/aiqc/aiqc/data/iris_10x.tsv
# https://github.com/aiqc/aiqc/remote_datum/image/brain_tumor/tabular_manifest.csv?raw=true

# %%
for n in names:
    print(datum.datum_to_pandas(file_name=n))
# Out:
#       TypeFlag  PlanetaryMassJpt   PeriodDays  SurfaceTempK  \
# 5            0            0.2500    19.224180         707.2
# 6            0            0.1700    39.031060         557.9
# 7            0            0.0220     1.592851        1601.5
# 15           0            1.2400     2.705782        2190.0
# 16           0            0.0195     1.580404         604.0
# ...        ...               ...          ...           ...
# 3557         0            0.2200     6.212290         783.1
# 3574         0            4.0630     4.124461        1161.5
# 3577         0            3.3280     5.452700        1335.3
# 3581         0            1.3600   395.400000         256.8
# 3582         0            1.0180  1605.800000         160.2
#
#       DistFromSunParsec  HostStarMassSlrMass  HostStarRadiusSlrRad  \
# 5                650.00                1.070                1.0200
# 6                650.00                1.070                1.0200
# ...

# %%
datum.datum_to_pandas(file_name='iris.tsv').dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species           int64
# dtype: object
